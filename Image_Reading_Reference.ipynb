# %% [markdown]
# # Single image

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/IMG_5666.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %% [markdown]
# # Read Image from a folder

# %%
import cv2
import os

folder_path = "/content/Image"
images = os.listdir(folder_path)

for img_name in images:
    img_path = os.path.join(folder_path, img_name)
    print("Reading:", img_path)
    img = cv2.imread(img_path)

    if img is None:  # If OpenCV fails to read the image
        print(f"Error loading image: {img_path}")
    else:
        img = cv2.resize(img, (512, 512))  # Resize image to 224x224
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.show()
# Out:
# Reading: /content/Image/1.jpg
# Reading: /content/Image/.ipynb_checkpoints
# Error loading image: /content/Image/.ipynb_checkpoints
# Reading: /content/Image/2.jpg
# Reading: /content/Image/3.jpg
